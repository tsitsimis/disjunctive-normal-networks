# %% [markdown]
# # Disjunctive Normal Networks
# ## Experiments with synthetic datasets
# Datasets:
# - Moons
# - Circles
# - Spirals

# %%
# !pip install --upgrade disjunctive_nn
# Out:
# Requirement already up-to-date: disjunctive_nn in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (0.1.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.19.1 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from disjunctive_nn) (1.19.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.3.0 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from disjunctive_nn) (3.3.0)
# Requirement already satisfied, skipping upgrade: torch>=1.6.0+cpu in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from disjunctive_nn) (1.6.0+cpu)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.23.2 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from disjunctive_nn) (0.23.2)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from matplotlib>=3.3.0->disjunctive_nn) (1.2.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from matplotlib>=3.3.0->disjunctive_nn) (0.10.0)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from matplotlib>=3.3.0->disjunctive_nn) (7.2.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from matplotlib>=3.3.0->disjunctive_nn) (2.8.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from matplotlib>=3.3.0->disjunctive_nn) (2.4.7)
# Requirement already satisfied, skipping upgrade: future in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from torch>=1.6.0+cpu->disjunctive_nn) (0.18.2)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from scikit-learn>=0.23.2->disjunctive_nn) (2.1.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from scikit-learn>=0.23.2->disjunctive_nn) (0.16.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from scikit-learn>=0.23.2->disjunctive_nn) (1.5.2)
# Requirement already satisfied, skipping upgrade: six in /home/tsitsimis/.pyenv/versions/3.8.5/envs/neural-decision-trees-env/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=3.3.0->disjunctive_nn) (1.15.0)

# %%
import numpy as np
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import torch

from disjunctive_nn import DisjunctiveNormalNetwork

# %%
cmap = ListedColormap(["#377eb8", "#ff7f00"])

# %% [markdown]
# ## Interleaving Half Circles (Moons)

# %%
n_samples = 400
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=0.2)

# %%
X, y = noisy_moons

scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
dnn = DisjunctiveNormalNetwork(n_polytopes=2, m=4)

# %%
# This cell was run multiple times until accuracy is maximized
dnn.fit(X_train, y_train, epochs=5000, lr=0.01, verbose=True)
# Out:
# Epoch: 0, Accuracy: 0.8958333333333334
# Epoch: 500, Accuracy: 0.9416666666666667
# Epoch: 1000, Accuracy: 0.9541666666666667
# Epoch: 1500, Accuracy: 0.9583333333333334
# Epoch: 2000, Accuracy: 0.9708333333333333
# Epoch: 2500, Accuracy: 0.9708333333333333
# Epoch: 3000, Accuracy: 0.9708333333333333
# Epoch: 3500, Accuracy: 0.9708333333333333
# Epoch: 4000, Accuracy: 0.975
# Epoch: 4500, Accuracy: 0.975
# DisjunctiveNormalNetwork(m=4, n_polytopes=2)

# %%
print(f"Accuracy: {dnn.score(X_test, y_test)}")
# Out:
# Accuracy: 0.98125

# %%
h = 0.01
xx, yy = np.meshgrid(
    np.arange(X[:, 0].min() - 0.1*abs(X[:, 0].min()), X[:, 0].max()*1.1, h),
    np.arange(X[:, 1].min() - 0.1*abs(X[:, 1].min()), X[:, 1].max()*1.1, h))
xy_pairs = np.c_[xx.ravel(), yy.ravel()]

# %%
y_pred = dnn.predict_proba(xy_pairs)

# %%
plt.figure(figsize=(6, 6))

plt.contourf(xx, yy, y_pred.reshape(xx.shape), cmap=cmap, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap, edgecolor="k")

plt.title("Disjunctive Normal Network")
plt.show()

# %% [markdown]
# #### Individual polytopes
# For intuition purposes the 2 polytopes forming the final network output are shown below

# %%
fig, ax = plt.subplots(1, dnn.n_polytopes, figsize=(15, 6))

for i, polytope in enumerate(dnn.polytopes):
    ax[i].contourf(xx, yy, polytope.value(xy_pairs).detach().numpy().reshape(xx.shape), cmap=cmap, alpha=0.8)
    ax[i].scatter(X[:, 0], X[:, 1], c=y, cmap=cmap, edgecolor="k")

plt.show()

# %% [markdown]
# ### Comparison with simple Decision Tree

# %%
simple_tree = DecisionTreeClassifier()
simple_tree.fit(X_train, y_train)

y_pred_dt = simple_tree.predict_proba(xy_pairs)[:, 1]

plt.figure(figsize=(6, 6))
plt.contourf(xx, yy, y_pred_dt.reshape(xx.shape), cmap=cmap, alpha=0.8)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap, edgecolor="k")

plt.title("Decision Tree")
plt.show()

# %%
simple_tree.get_depth()
# Out:
# 8

# %%
print(f"Accuracy: {simple_tree.score(X_test, y_test)}")
# Out:
# Accuracy: 0.95625

# %% [markdown]
# ## Circles

# %%
n_samples = 400
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=0.5, noise=0.1)

# %%
X, y = noisy_circles

# %%
plt.figure(figsize=(6, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
dnn = DisjunctiveNormalNetwork(n_polytopes=1, m=4)

# %%
dnn.fit(X_train, y_train, epochs=1000, lr=0.1)
# Out:
# DisjunctiveNormalNetwork(m=4, n_polytopes=1)

# %%
print(f"Accuracy: {dnn.score(X_test, y_test)}")
# Out:
# Accuracy: 0.96875

# %%
h = 0.01
xx, yy = np.meshgrid(
    np.arange(X[:, 0].min() - 0.1*abs(X[:, 0].min()), X[:, 0].max()*1.1, h),
    np.arange(X[:, 1].min() - 0.1*abs(X[:, 1].min()), X[:, 1].max()*1.1, h))
xy_pairs = np.c_[xx.ravel(), yy.ravel()]

# %%
y_pred = dnn.predict_proba(xy_pairs)

# %%
plt.figure(figsize=(6, 6))

plt.contourf(xx, yy, y_pred.reshape(xx.shape), cmap=cmap, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap, edgecolor="k")

plt.title("Disjunctive Normal Network")
plt.show()

# %% [markdown]
# ### Comparison with simple Decision Tree

# %%
simple_tree = DecisionTreeClassifier()
simple_tree.fit(X_train, y_train)

y_pred_dt = simple_tree.predict_proba(xy_pairs)[:, 1]

plt.figure(figsize=(6, 6))
plt.contourf(xx, yy, y_pred_dt.reshape(xx.shape), cmap=cmap, alpha=0.8)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap, edgecolor="k")

plt.title("Decision Tree")
plt.show()

# %%
simple_tree.get_depth()
# Out:
# 6

# %%
print(f"Accuracy: {simple_tree.score(X_test, y_test)}")
# Out:
# Accuracy: 0.9625

# %% [markdown]
# ## Spirals

# %%
def spirals(points, noise=0.5):
    n = np.sqrt(np.random.rand(points,1)) * int(360*1.8) * (2*np.pi)/360
    d1x = -np.cos(n)*n + np.random.rand(points,1) * noise
    d1y = np.sin(n)*n + np.random.rand(points,1) * noise
    return (np.vstack((np.hstack((d1x,d1y)),np.hstack((-d1x,-d1y)))), 
            np.hstack((np.zeros(points),np.ones(points))))

# %%
n_samples = 400
noisy_spirals = spirals(n_samples, noise=1)

# %%
X, y = noisy_spirals

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap)
plt.show()

# %%
dnn = DisjunctiveNormalNetwork(n_polytopes=20, m=10)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
# This cell was run multiple times until accuracy is maximized
dnn.fit(X_train, y_train, epochs=1000, lr=0.1, verbose=True)
# Out:
# Epoch: 0, Accuracy: 0.9666666666666667
# Epoch: 100, Accuracy: 0.9708333333333333
# Epoch: 200, Accuracy: 0.9708333333333333
# Epoch: 300, Accuracy: 0.9708333333333333
# Epoch: 400, Accuracy: 0.9770833333333333
# Epoch: 500, Accuracy: 0.98125
# Epoch: 600, Accuracy: 0.98125
# Epoch: 700, Accuracy: 0.9854166666666667
# Epoch: 800, Accuracy: 0.9875
# Epoch: 900, Accuracy: 0.99375
# DisjunctiveNormalNetwork(m=10, n_polytopes=20)

# %%
print(f"Accuracy: {dnn.score(X_test, y_test)}")
# Out:
# Accuracy: 0.990625

# %%
h = 0.01
xx, yy = np.meshgrid(
    np.arange(X[:, 0].min() - 0.1*abs(X[:, 0].min()), X[:, 0].max()*1.1, h),
    np.arange(X[:, 1].min() - 0.1*abs(X[:, 1].min()), X[:, 1].max()*1.1, h))
xy_pairs = np.c_[xx.ravel(), yy.ravel()]

# %%
y_pred = dnn.predict_proba(xy_pairs)

# %%
plt.figure(figsize=(6, 6))

plt.contourf(xx, yy, y_pred.reshape(xx.shape), cmap=cmap, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap, edgecolor="k")

plt.title("Disjunctive Normal Network")
plt.show()

# %% [markdown]
# ### Comparison with simple Decision Tree

# %%
simple_tree = DecisionTreeClassifier()
simple_tree.fit(X_train, y_train)

y_pred_dt = simple_tree.predict_proba(xy_pairs)[:, 1]

plt.figure(figsize=(6, 6))
plt.contourf(xx, yy, y_pred_dt.reshape(xx.shape), cmap=cmap, alpha=0.8)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap, edgecolor="k")

plt.title("Decision Tree")
plt.show()

# %%
simple_tree.get_depth()
# Out:
# 15

# %%
print(f"Accuracy: {simple_tree.score(X_test, y_test)}")
# Out:
# Accuracy: 0.959375
